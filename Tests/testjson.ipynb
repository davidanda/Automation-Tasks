# %%
import json
import requests

# %%
#r = "C:\Users\Raimi Anda\Desktop\testamari.json"
# read file
with open('playlistvideosjson.json', 'r') as myfile:
    data = myfile.read()

# %%
obj = json.loads(data)
obj
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '3EhJx0s6gOHPhEYPpilWwwiPj98',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'qVnH3YsgB0vJm-Pj57nreKKyK1g',
#    'id': 'UExCQ0YyREFDNkZGQjU3NERFLkE2OTA3QzIwNEI3RjYxMDE',
#    'snippet': {'publishedAt': '2013-10-18T14:55:24Z',
#     'channelId': 'UCvceBgMIpKb4zK1ss-Sh90w',
#     'title': 'Andrew Willis, Skatepark Engineer',
#     'description': 'Andrew Willis built a skatepark in East London using reclaimed materials left over from the Olympic Games, creating a lasting legacy for the local community of Hackney Wick.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GvgqDSnpRQM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GvgqDSnpRQM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GvgqDSnpRQM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
# ...

# %%
obj["items"][4]["contentDetails"]
# Out:
# {'videoId': 'XDgC4FMftpg', 'videoPublishedAt': '2011-11-21T20:36:57Z'}

# %%
for item in obj["items"]:
    video_title = item["snippet"]["title"]
    print(video_title)
# Out:
# Andrew Willis, Skatepark Engineer
# Private video
# Mark Lesek: A New/Old Prosthetic
# Private video
# Mark Kempton: Neighbors In Need
# Zack Matere: Growing Knowledge
# Mitch Dobrowner: Epic Storms
# The Tofino Riders: A 1,000 Year-Old-Wave
# David Kennedy: Ancient Ruins
# Caroline: Supernova 2008ha
# Private video
# Erik-Jan Bos: A Letter from an Old Friend
# Cheryl and Morgan: Learning Independence

# %%
for item in obj["items"]:
    for i in range(len(obj))
    video_id = item[i]["snippet"]["resourceId"]["videoId"]
    print(video_id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-dff737bc9400> in <module>
# ----> 1 for i, item in obj["items"]:
#       2     video_id = item[i]["snippet"]["resourceId"]["videoId"]
#       3     print(video_id)
#
# ValueError: too many values to unpack (expected 2)

# %%
len(obj["items"])
# Out:
# 13

# %%
for i in range(len(obj["items"])):
    video_id = obj["items"][i]["snippet"]["resourceId"]["videoId"]
    print(video_id)
# Out:
# GvgqDSnpRQM
# fIc_VEQ7Vo0
# V4DDt30Aat4
# 07718Vcwcyc
# XDgC4FMftpg
# OE63BYWdqC4
# RQbmXxU2dkg
# 7nJdEXpvi1g
# 7hakGJU9xco
# x9-F6dbCIHw
# gK7lUK0711E
# 18TknKGC7tY
# CyRQJBBVI7g

# %%
len(obj["items"])
# Out:
# 13

# %%
obj["items"][0]["snippet"]["title"]
# Out:
# 'Andrew Willis, Skatepark Engineer'

# %%
obj["items"][0]["snippet"]["resourceId"]["videoId"]
# Out:
# 'GvgqDSnpRQM'

# %%
obj["tracks"]["items"]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
# ...

# %%
obj["items"][1]['position']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-105b4aa3fba0> in <module>
# ----> 1 obj["items"][1]['position']
#
# KeyError: 'position'

# %%
songs[0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
# ...

# %%
songs[0]["uri"]
# Out:
# 'spotify:track:13e6f8t7RKXuxZ0JdaaJRG'
